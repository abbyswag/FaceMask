# %% [markdown]
# # FaceMap

# %% [markdown]
# An web application for mapping random guesses of an individual's image to it's expected career.

# %% [markdown]
# A mini fun project by ELSOC, and sponcered by DualNature.

# %% [markdown]
# Used Technologies:
#     Python --3.8,
#     JavaScript --ES6,
#     HTML --5,
#     CSS --3

# %% [markdown]
# Used Libraries/Frameworks:
#     Flask,
#     React,
#     Sass
